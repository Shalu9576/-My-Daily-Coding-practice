# %% [markdown]
# ## Plotting for Exploraroty Data analysis(EDA)
#
# ## Basic Terminology
#
# - What is EDA?
# - Data-point/vector/observation
# - Data-set
# - Feature/variable/input-variable/independent-varible
# - Label/depdendent-variable/output-variable/class/class-label/Response   Label
# - Vector: 2-D,3-D,4-D,...n-D
#
# Q. What is a 1-D vector :scalar

# %% [markdown]
# ## Iris Flower dataset
# Iris  Dataset:
# https://www.kaggle.com/datasets/uciml/iris
# - A sample dataset to learn the basics.
# - 3 flower of Iris species
#
# Objective: Classify a new flower as belonging to one of the 3 classes given the 4 features.
#
# - importance of domain knowledge
# - Why use petal and sepal dimesnion as features?
# - Why do we use 'color' as a feature?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#load iris.csv into a pandas dataframe.
iris = pd.read_csv("C:/Users/Lenovo/Desktop/Machine learning/Iris.csv")

# %%
#finding data points and features
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# How many data points for each class are present?
#(or) How many flowers of each species are present?
iris["Species"].value_counts()
#Iris is a balances dataset as the number of data points a for every class is equal
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## 2-D Scatter Plot

# %%
iris.plot(kind="scatter",x= "SepalLengthCm", y= "SepalWidthCm");
plt.show()

# %%
# 2-D scatter plot with color -coding for each flower type/class
#here sns correspond to seaborn.
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="Species", height=4) \
    .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
    .add_legend()
plt.show()

# %% [markdown]
# *Observation(s):
# 1. Using SepalLengtCm and SepalWidthCm features, we can distinngush Setosa flower from others.
# 2. Separing Versicolor from v

# %%
iris.plot(kind="scatter",x= "PetalLengthCm", y= "PetalWidthCm");
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="Species", height=4) \
    .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
    .add_legend()
plt.show()
